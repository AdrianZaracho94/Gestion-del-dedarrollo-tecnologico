# %%
import pandas as pd

# %%
df = pd.read_csv('out.csv')
lista_cols = list(df.columns)

# %%
decodificacion = {
    'Ã¡': 'á',
    'Ã': 'Á',
    'Ã©': 'é',
    'Ã‰': 'É',
    'Ã': 'Í',
    'Ã³': 'ó',
    'Ã“': 'Ó',
    'Ãº': 'ú',
    'Ãš': 'Ú',
    'Ã‘': 'Ñ',
    'Ã±': 'ñ',
    'Â¿': '¿',
    'Ã': 'í'
}

# %%
for i in lista_cols:
    df[i] = df[i].apply(str)
    for clave, valor in decodificacion.items():
        df[i] = df[i].str.replace(f'{clave}', f'{valor}')

# %%
df.head(25)
# Out:
#    Unnamed: 0   Id_recorrido duracion_recorrido fecha_origen_recorrido  \
# 0           1  9379BAEcobici                239    2019-02-27 19:44:42
# 1           2  7441BAEcobici              2,814    2019-02-27 14:35:58
# 2           3  6828BAEcobici                298    2019-02-27 11:51:40
# 3           4  7485BAEcobici              2,324    2019-02-27 14:45:57
# 4           5  6111BAEcobici              1,215    2019-02-27 07:46:13
# 5           6  8988BAEcobici              1,191    2019-02-27 18:50:37
# 6           7  7870BAEcobici              1,458    2019-02-27 16:04:36
# 7           8  6998BAEcobici                122    2019-02-27 12:44:37
# 8           9  9473BAEcobici              2,613    2019-02-27 20:02:43
# 9          10  9878BAEcobici              1,688    2019-02-27 21:58:16
# 10         11  8440BAEcobici              1,434    2019-02-27 17:39:51
# 11         12  9849BAEcobici              1,132    2019-02-27 21:33:11
# ...

# %% [markdown]
# á Ã¡
# Á Ã
# é Ã©
# É Ã‰
# í Ã­
# Í Ã
# ó Ã³
# Ó Ã“
# ú Ãº
# Ú Ãš
# Ñ Ã‘
# ñ Ã±
# ¿ Â¿
